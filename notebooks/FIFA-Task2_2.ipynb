# %% [markdown]
# # Data Analysis Project on FIFA dataset
#
# * #### The given data contains the data of 1500+ unique instances and has 13 columns
# * #### The data will be cleaned and plotted as per required for understanding and will be made ready further use

# %%
# Importing all libraries that will be required for this project

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Making a dataframe from the given data

df = pd.read_csv("/home/smayan/Desktop/Smayan_Kulkarni_S4DS/Smayan_Kulkarni_S4DS/data/TASK2- DATA.csv")
#df = pd.read_csv("/workspaces/Smayan_Kulkarni_S4DS/data/TASK2- DATA.csv")

# %%
# For convenient viewing of the data

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Getting a small view of the data

df.head(20)
# Out:
#     Season            Competition     Matchday      Date Venue  \
# 0    15/16                 LaLiga           26   2/28/16     H
# 1    2O/21                    NaN          NaN       NaN     A
# 2    16/17                 LaLiga           25  O3-O1-17     H
# 3   Dec-13                 LaLiga           36  O5-O8-13     H
# 4    22/23  UEFA Champions League  Group Stage   1O/5/22     A
# 5    15/16  UEFA Champions League      last 16  O3-O8-16     H
# 6    15/16                 LaLiga           3O   3/2O/16     H
# 7    15/16                 LaLiga            3  O9-12-15     A
# 8      NaN                    NaN          NaN  11/2O/1O   NaN
# 9    13/14                 LaLiga           24   2/15/14     H
# 10   1O/11  UEFA Champions League  Group Stage  11-O2/1O     A
# 11   1O/11                 LaLiga            9  1O/3O/1O     H
# 12   O5/O6                EFL Cup        Final   2/26/O6     H
# 13   17/18                 LaLiga           31  O4/O7-18     H
# ...

# %%
# Understanding the statistical information in the dataset

df.describe()
# Out:
#        Season Competition     Matchday     Date Venue          Club  \
# count    1511        1497         1507     1498  1504          1508
# unique     22          21           53      852     2             7
# top     14/15      LaLiga  Group Stage  1/27/13     H  FC Barcelona
# freq      127         831          164        8   875           717
#
#           Opponent Result Playing_Position Minute At_score              Type  \
# count         1500   1500             1435   1500     1507              1475
# unique         174     72                5    108       54                12
# top     Sevilla FC   3:OO               CF     9O     1:OO  Left-footed shot
# freq            71     99              552     32      219               589
#
#         Goal_assist
# count          1012
# unique          159
# top     Luis Suarez
# freq             52

# %%
# Checking the rows and columns in the dataframe

df.shape
# Out:
# (1564, 13)

# %%
# Getting crucial information of the dataframe such as data types and null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            1511 non-null   object
#  1   Competition       1497 non-null   object
#  2   Matchday          1507 non-null   object
#  3   Date              1498 non-null   object
#  4   Venue             1504 non-null   object
#  5   Club              1508 non-null   object
#  6   Opponent          1500 non-null   object
#  7   Result            1500 non-null   object
#  8   Playing_Position  1435 non-null   object
#  9   Minute            1500 non-null   object
#  10  At_score          1507 non-null   object
#  11  Type              1475 non-null   object
#  12  Goal_assist       1012 non-null   object
# dtypes: object(13)
# memory usage: 159.0+ KB

# %%
# Checking the data types in the dataframe

df.dtypes
# Out:
# Season              object
# Competition         object
# Matchday            object
# Date                object
# Venue               object
# Club                object
# Opponent            object
# Result              object
# Playing_Position    object
# Minute              object
# At_score            object
# Type                object
# Goal_assist         object
# dtype: object

# %% [markdown]
# *  **Here it is seen that even all numerical values are of object type, thus to perform any statistical analysis on them the feasible ones should be converted to integer or float type**

# %%
df.isnull().sum()
# Out:
# Season               53
# Competition          67
# Matchday             57
# Date                 66
# Venue                60
# Club                 56
# Opponent             64
# Result               64
# Playing_Position    129
# Minute               64
# At_score             57
# Type                 89
# Goal_assist         552
# dtype: int64

# %%
df['Minute'].unique()
# Out:
# array(['31', '89', '9', '26', '22', '64', '81', nan, '36', '63', '59',
#        '32', '87', '68', '74', '55', '11', '86', '8O', '51', '85', '49',
#        '45', '3O', '88', '53', '76', '72', '54', '42', '9O', '25', '39',
#        '16', '28', '73', '12', '18', '45+1', '27', '44', '7O', '13', '71',
#        '77', '82', '9O+1', '65', '78', '47', '75', '3', '37', '69', '8',
#        '57', '61', '1O', '17', '21', '24', '41', '83', '23', '2', '33',
#        '5', '58', '45+2', '43', '62', '2O', '46', '29', '4O', '48', '56',
#        '6O', '38', '4', '9O+6', '15', '34', '9O+2', '52', '35', '66',
#        '67', '19', '84', '1', '5O', '79', '6', '9O+4', '11O', '1O4',
#        '9O+3', '12O', '97', '14', '7', '45+7', '1O3', '45+4', '9O+5',
#        '1O9', '9O+7', '1O5'], dtype=object)

# %% [markdown]
# Here we can see that there are many values which are denoted as "90+1", denoting overtime
# We must take care of such values and combine them to form a single integral time

# %%
df['Minute'].isnull().sum()
# Out:
# 64

# %% [markdown]
# * Here we can see that many values under 'Minute' are null, we must take care of such values before diving deeper into optimizing the data

# %% [markdown]
#  * ####  **To optimize the 'Minute' column as per the condition here, we will split the data into two columns, one for before the '+' and one for after '+' then we will convert those columns to integer type and add them to have a final 'Main_Time' value**

# %%
# Splitting the data
df[['time1','time2']]=df['Minute'].str.split('+', expand=True)

# %%
# Filling all NaN values
df['time2']=df['time2'].fillna(0)
df['time1']=df['time1'].fillna(0)

# %%
# Checking all unique values in the columns to check possibility of non numeric instances
df['time2'].unique(),df['time1'].unique()
# Out:
# (array([0, '1', '2', '6', '4', '3', '7', '5'], dtype=object),
#  array(['31', '89', '9', '26', '22', '64', '81', 0, '36', '63', '59', '32',
#         '87', '68', '74', '55', '11', '86', '8O', '51', '85', '49', '45',
#         '3O', '88', '53', '76', '72', '54', '42', '9O', '25', '39', '16',
#         '28', '73', '12', '18', '27', '44', '7O', '13', '71', '77', '82',
#         '65', '78', '47', '75', '3', '37', '69', '8', '57', '61', '1O',
#         '17', '21', '24', '41', '83', '23', '2', '33', '5', '58', '43',
#         '62', '2O', '46', '29', '4O', '48', '56', '6O', '38', '4', '15',
#         '34', '52', '35', '66', '67', '19', '84', '1', '5O', '79', '6',
#         '11O', '1O4', '12O', '97', '14', '7', '1O3', '1O9', '1O5'],
#        dtype=object))

# %%
df.dtypes
# Out:
# Season              object
# Competition         object
# Matchday            object
# Date                object
# Venue               object
# Club                object
# Opponent            object
# Result              object
# Playing_Position    object
# Minute              object
# At_score            object
# Type                object
# Goal_assist         object
# time1               object
# time2               object
# dtype: object

# %% [markdown]
# * #### From here we conclude that 'time1' and 'time2' may contain non numeric values, those values are handled below before converting them into integer type

# %%
df['time1']=df['time1'].astype(str)
df['time2']=df['time2'].astype(str)

# %%
non_numeric1 = df[~df['time1'].str.isnumeric()]
non_numeric2 = df[~df['time2'].str.isnumeric()]

# %%
df['time1'] = pd.to_numeric(df['time1'], errors='coerce')
df['time2']=pd.to_numeric(df['time2'],errors='coerce')

# %%
df['time2'].unique()
# Out:
# array([0, 1, 2, 6, 4, 3, 7, 5])

# %%
df['time1'] = df['time1'].astype(float)
df['time2']=df['time2'].astype(float)

# %%
df.dtypes
# Out:
# Season               object
# Competition          object
# Matchday             object
# Date                 object
# Venue                object
# Club                 object
# Opponent             object
# Result               object
# Playing_Position     object
# Minute               object
# At_score             object
# Type                 object
# Goal_assist          object
# time1               float64
# time2               float64
# dtype: object

# %% [markdown]
# * 'time1' and 'time2' have been converted to integer type, now we can create a final column and drop the unnecessary ones

# %%
df['Main_Time'] = df['time1']+df['time2']
type(df['Main_Time'][0])
# Out:
# numpy.float64

# %%
df.drop(['time1','time2','Minute'], axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    Season            Competition     Matchday      Date Venue  \
# 0   15/16                 LaLiga           26   2/28/16     H
# 1   2O/21                    NaN          NaN       NaN     A
# 2   16/17                 LaLiga           25  O3-O1-17     H
# 3  Dec-13                 LaLiga           36  O5-O8-13     H
# 4   22/23  UEFA Champions League  Group Stage   1O/5/22     A
# 5   15/16  UEFA Champions League      last 16  O3-O8-16     H
# 6   15/16                 LaLiga           3O   3/2O/16     H
# 7   15/16                 LaLiga            3  O9-12-15     A
# 8     NaN                    NaN          NaN  11/2O/1O   NaN
# 9   13/14                 LaLiga           24   2/15/14     H
#
#                   Club                Opponent Result Playing_Position  \
# 0         FC Barcelona              Sevilla FC   2:O1               RW
# 1         FC Barcelona                     NaN   1:OO              NaN
# ...

# %% [markdown]
# ## Understanding the Amount of null values in the DataFrame

# %%
df.isnull().sum()
# Out:
# Season               53
# Competition          67
# Matchday             57
# Date                 66
# Venue                60
# Club                 56
# Opponent             64
# Result               64
# Playing_Position    129
# At_score             57
# Type                 89
# Goal_assist         552
# Main_Time           217
# dtype: int64

# %%
def get_null_percentages(df, columns):
    result = {}
    for col in columns:
        if col in df.columns:
            null_count = df[col].isnull().sum()
            total_count = len(df)
            null_percentage = (null_count / total_count) * 100
            result[col] = round(null_percentage, 2)
        else:
            result[col] = "Column not found"

    return result

columns_checking=['Goal_assist', 'Main_Time','Playing_Position','Competition']
null_percentage = get_null_percentages(df, columns_checking)

for column, percentage in null_percentage.items():
    if isinstance(percentage, float):
        print(f"{column}: {percentage}%")
    else:
        print(f"{column}: {percentage}")
# Out:
# Goal_assist: 35.29%
# Main_Time: 13.87%
# Playing_Position: 8.25%
# Competition: 4.28%

# %%
sns.barplot(data=null_percentage, x=null_percentage.values(), y=null_percentage.keys(), palette='viridis', hue=null_percentage.keys()).set(title="Percentage of Missing Values", xlabel="Percentage (%)", ylabel="Features")
plt.show()

# %% [markdown]
# * #### **Here Goal Assist is the name of the player who has assisted in scoring the goal, so using a process to fill the value of the empty instance wont make sense, it could make sense to make it a target variable and then while taking Competition, Match Day, Club and Playing Position it can be predicted with some accuracy who the player could be in the given empty instance. It can prove to be a valuable feature so its preferred not to drop it.**
# * #### **Here Main_Time is the time at which most goals have been scored, the values in this column can be filled by a statistical method.**
# * #### **Here Playing_Position has a null percentage of less than 10% so we need not perform deep analysis into this column.**
# * **All other vaues like competition have very less null values so they can all be dropped**

# %%
df.isnull().sum()
# Out:
# Season               53
# Competition          67
# Matchday             57
# Date                 66
# Venue                60
# Club                 56
# Opponent             64
# Result               64
# Playing_Position    129
# At_score             57
# Type                 89
# Goal_assist         552
# Main_Time           217
# dtype: int64

# %%
df.dropna(subset=['Season','Competition','Matchday','Date','Venue','Club','Opponent','Result','At_score','Type','Playing_Position'], inplace=True)
df.shape
# Out:
# (1391, 13)

# %%
df.isnull().sum()
# Out:
# Season                0
# Competition           0
# Matchday              0
# Date                  0
# Venue                 0
# Club                  0
# Opponent              0
# Result                0
# Playing_Position      0
# At_score              0
# Type                  0
# Goal_assist         445
# Main_Time           204
# dtype: int64

# %%
stdn = df['Main_Time'].std()

# %%
stdn
# Out:
# 24.90542644495138

# %% [markdown]
# * **The standard deviation in this case is quite high so the null values will not be filled with the mean values of the dataset**
# * **The standard deviation of around 26.5 means that there must be many outliers in the data for goal times, such as very early goals or very late goals deep into extra time, in this dataset there have been quite a few early goals.**

# %%
mn = df['Main_Time'].mean()    
mn
# Out:
# 48.517270429654594

# %%
df['Main_Time'].unique().sum()
# Out:
# nan

# %%
def fill_goal_assist_with_mode(df, competition_col, assist_col):
    
    mode_values = df.groupby(competition_col)[assist_col].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None)
    
    def fill_na(row):
        if pd.isna(row[assist_col]):
            return mode_values[row[competition_col]]
        else:
            return row[assist_col]

    df[assist_col] = df.apply(fill_na, axis=1)
    return df

df_filled = fill_goal_assist_with_mode(df, 'Competition', 'Goal_assist')

# %%
df.head(20)
# Out:
#     Season            Competition     Matchday      Date Venue  \
# 0    15/16                 LaLiga           26   2/28/16     H
# 2    16/17                 LaLiga           25  O3-O1-17     H
# 3   Dec-13                 LaLiga           36  O5-O8-13     H
# 4    22/23  UEFA Champions League  Group Stage   1O/5/22     A
# 5    15/16  UEFA Champions League      last 16  O3-O8-16     H
# 6    15/16                 LaLiga           3O   3/2O/16     H
# 7    15/16                 LaLiga            3  O9-12-15     A
# 9    13/14                 LaLiga           24   2/15/14     H
# 10   1O/11  UEFA Champions League  Group Stage  11-O2/1O     A
# 11   1O/11                 LaLiga            9  1O/3O/1O     H
# 13   17/18                 LaLiga           31  O4/O7-18     H
# 14   15/16                 LaLiga           24   2/13/16     H
# 15   O8/O9         Premier League           34   4/25/O9     H
# 16   13/14  UEFA Champions League      last 16   3/18/14     H
# ...

# %%
Q1 = df['Main_Time'].quantile(0.25)
Q3 = df['Main_Time'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['Main_Time'] < lower_bound) | (df['Main_Time'] > upper_bound)]

# %%
lower_bound
# Out:
# -36.0

# %%
upper_bound
# Out:
# 132.0

# %%
df['Date'].unique()
# Out:
# array(['2/28/16', 'O3-O1-17', 'O5-O8-13', '1O/5/22', 'O3-O8-16',
#        '3/2O/16', 'O9-12-15', '2/15/14', '11-O2/1O', '1O/3O/1O',
#        'O4/O7-18', '2/13/16', '4/25/O9', '3/18/14', '2/14/O4', '12-O3/11',
#        'O4-O5-O9', 'O8/O6-22', '12-O8-O9', '8/29/11', '12-O9-17',
#        '3/17/19', '2/16/13', '3/19/17', '1/3O/2O', '11/O6-13', '12/16/12',
#        '1/13/19', 'O3-O6-1O', 'O3-O3-16', '7/2O/2O', 'O4/O6/1O',
#        'O1/O8-17', 'O3/O7-2O', '1/18/15', '1O-O1-14', '2/22/2O',
#        '2/24/18', '11/11-18', '3/16/14', '4/17/16', 'O4/O6-19', '8/23/12',
#        '3/2O/12', '9/23/14', '8/23/O9', '11/29/2O', '3/18/18', '11-O9-13',
#        '2/25/23', '11/26/O8', '12/18/O8', '4/29/17', 'O4/O7/12',
#        '9/3O/12', 'O1/O6-13', '12-12-14', '9/14/21', 'O3-O2/11',
#        'O3-O2-14', '5/17/15', 'O2-O1/O9', '1/21/18', '11/21/17',
#        '9/18/13', '8/29/1O', '3/24/12', 'O5-O2-15', '9/19/12', '1O/19/16',
#        '9/24/13', '3/14/15', '11-O2-11', '1/22/2O', '1/25/14', 'O7-O4-2O',
# ...

# %%
df['Date2'] = df['Date'].astype(str)
df.dtypes
# Out:
# Season               object
# Competition          object
# Matchday             object
# Date                 object
# Venue                object
# Club                 object
# Opponent             object
# Result               object
# Playing_Position     object
# At_score             object
# Type                 object
# Goal_assist          object
# Main_Time           float64
# Date2                object
# dtype: object

# %%
type(df['Date2'][0])
# Out:
# str

# %%
df['Date2']= df['Date2'].str.replace('/', '-')

# %%
df['Date2'].unique()
# Out:
# array(['2-28-16', 'O3-O1-17', 'O5-O8-13', '1O-5-22', 'O3-O8-16',
#        '3-2O-16', 'O9-12-15', '2-15-14', '11-O2-1O', '1O-3O-1O',
#        'O4-O7-18', '2-13-16', '4-25-O9', '3-18-14', '2-14-O4', '12-O3-11',
#        'O4-O5-O9', 'O8-O6-22', '12-O8-O9', '8-29-11', '12-O9-17',
#        '3-17-19', '2-16-13', '3-19-17', '1-3O-2O', '11-O6-13', '12-16-12',
#        '1-13-19', 'O3-O6-1O', 'O3-O3-16', '7-2O-2O', 'O4-O6-1O',
#        'O1-O8-17', 'O3-O7-2O', '1-18-15', '1O-O1-14', '2-22-2O',
#        '2-24-18', '11-11-18', '3-16-14', '4-17-16', 'O4-O6-19', '8-23-12',
#        '3-2O-12', '9-23-14', '8-23-O9', '11-29-2O', '3-18-18', '11-O9-13',
#        '2-25-23', '11-26-O8', '12-18-O8', '4-29-17', 'O4-O7-12',
#        '9-3O-12', 'O1-O6-13', '12-12-14', '9-14-21', 'O3-O2-11',
#        'O3-O2-14', '5-17-15', 'O2-O1-O9', '1-21-18', '11-21-17',
#        '9-18-13', '8-29-1O', '3-24-12', 'O5-O2-15', '9-19-12', '1O-19-16',
#        '9-24-13', '3-14-15', '11-O2-11', '1-22-2O', '1-25-14', 'O7-O4-2O',
# ...

# %%
df[['month','day','year']]=df['Date2'].str.split('-', expand=True)
df.shape
# Out:
# (1391, 17)

# %%
df.drop('Date2', axis=1,inplace=True)
df.shape
# Out:
# (1391, 16)

# %%
df.drop('Date',axis=1, inplace=True)

# %%
df.shape
# Out:
# (1391, 15)

# %%
df.dropna(subset = ['year'], inplace=True)
df.dropna(subset = ['day'], inplace=True)
df.head(20)
# Out:
#     Season            Competition     Matchday Venue                 Club  \
# 0    15/16                 LaLiga           26     H         FC Barcelona
# 2    16/17                 LaLiga           25     H         FC Barcelona
# 3   Dec-13                 LaLiga           36     H          Real Madrid
# 4    22/23  UEFA Champions League  Group Stage     A  Paris Saint-Germain
# 5    15/16  UEFA Champions League      last 16     H          Real Madrid
# 6    15/16                 LaLiga           3O     H          Real Madrid
# 7    15/16                 LaLiga            3     A          Real Madrid
# 9    13/14                 LaLiga           24     H         FC Barcelona
# 10   1O/11  UEFA Champions League  Group Stage     A         FC Barcelona
# 11   1O/11                 LaLiga            9     H         FC Barcelona
# 13   17/18                 LaLiga           31     H         FC Barcelona
# 14   15/16                 LaLiga           24     H          Real Madrid
# ...

# %%
df['Main_Time'].isnull().sum()
# Out:
# 204

# %%
df = df.reset_index()
df.drop('index', inplace=True, axis=1)

# %%
df.shape
# Out:
# (1391, 15)

# %% [markdown]
# * **Since there were only 66 null values in both out of over 1500 they are dropped**

# %%
df['day']=df['day'].str.replace('O','').astype(int)
df['month']=df['month'].str.replace('O','').astype(int)
df['year']=df['year'].str.replace('O','0').astype(int)

# %%
df['year'].unique()
# Out:
# array([16, 17, 13, 22, 15, 14, 10, 18,  9,  4, 11, 19, 20, 12, 23,  8, 21,
#         6,  7,  5,  3,  2])

# %%
df.head(10)
# Out:
#    Season            Competition     Matchday Venue                 Club  \
# 0   15/16                 LaLiga           26     H         FC Barcelona
# 1   16/17                 LaLiga           25     H         FC Barcelona
# 2  Dec-13                 LaLiga           36     H          Real Madrid
# 3   22/23  UEFA Champions League  Group Stage     A  Paris Saint-Germain
# 4   15/16  UEFA Champions League      last 16     H          Real Madrid
# 5   15/16                 LaLiga           3O     H          Real Madrid
# 6   15/16                 LaLiga            3     A          Real Madrid
# 7   13/14                 LaLiga           24     H         FC Barcelona
# 8   1O/11  UEFA Champions League  Group Stage     A         FC Barcelona
# 9   1O/11                 LaLiga            9     H         FC Barcelona
#
#                  Opponent Result Playing_Position At_score               Type  \
# 0              Sevilla FC   2:O1               RW     1:O1   Direct free kick
# ...

# %%
df['Season'] = df['Season'].str.replace('O','0')

# %%
df['Result'] = df['Result'].str.replace('O','0')

# %%
df['At_score']=df['At_score'].str.replace('O','0')

# %% [markdown]
# * **These indexes have values that will need more assessment:  189, 358, 363, 961**

# %%
df['Result']=df['Result'].str.replace('AET','')
df['Result']= df['Result'].str.replace(' on pens','')

# %%
df['Result'].unique()
# Out:
# array(['2:01', '6:01', '6:02', '1:1', '2:00', '4:00', '0:06', '6:00',
#        '1:01', '5:00', '3:01', '4:02', '5:02', '3:02', '0:05', '1:03',
#        '1:04', '1:02', '4:01', '3:00', '1:05', '1:00', '0:04', '3:04',
#        '7:00', '5:03', '5:01', '6:03', '0:3', '2:05', '3:05', '0:01',
#        '2:02', '7:01', '0:03', '0:02', '2:03', '4:05', '0:08', '2:04',
#        '1:06', '7:03', '3:03', '10:02', '8:01', '2:1', '0:4', '7:2',
#        '4:03', '2:06', '3:0', '1:2 ', '8:00', '0:07', '1:3', '6:5',
#        '4:2 ', '2:2', '4:1 ', '4:04', '4:2', '9:01', '0:1 ', '3:4',
#        '8:02', '5:4 ', '4:3', '2:0', '2:1 ', '2:08', '1:07'], dtype=object)

# %%
df['At_score'].unique()
# Out:
# array(['1:01', '1:00', '2:01', '0:1', '2:00', '0:06', '0:01', '4:00',
#        '4:01', '3:02', '3:00', '0:05', '1:03', '1:04', '5:00', '1:02',
#        '3:01', '6:00', '0:03', '0:02', '2:02', '5:01', '0:04', '0:2',
#        '2:04', '1:05', '5:02', '3:03', '4:02', '1:0', '2:03', '1:1',
#        '7:00', '4:1', '0:3', '3:04', '3:0', '1:06', '6:01', '0:07', '2:2',
#        '0:4', '6:02', '4:03', '6:03', '9:01', '2:0', '2:1', '8:00',
#        '2:05', '7:01', '4:3', '3:05'], dtype=object)

# %%
df['Matchday'] = df['Matchday'].str.replace('O','0')

# %%
df.head(10)
# Out:
#    Season            Competition     Matchday Venue                 Club  \
# 0   15/16                 LaLiga           26     H         FC Barcelona
# 1   16/17                 LaLiga           25     H         FC Barcelona
# 2  Dec-13                 LaLiga           36     H          Real Madrid
# 3   22/23  UEFA Champions League  Group Stage     A  Paris Saint-Germain
# 4   15/16  UEFA Champions League      last 16     H          Real Madrid
# 5   15/16                 LaLiga           30     H          Real Madrid
# 6   15/16                 LaLiga            3     A          Real Madrid
# 7   13/14                 LaLiga           24     H         FC Barcelona
# 8   10/11  UEFA Champions League  Group Stage     A         FC Barcelona
# 9   10/11                 LaLiga            9     H         FC Barcelona
#
#                  Opponent Result Playing_Position At_score               Type  \
# 0              Sevilla FC   2:01               RW     1:01   Direct free kick
# ...

# %%
def convert_format(score):
  parts = score.split(':')
  parts[1] = parts[1].lstrip('0') or '0'  
  return ':'.join(parts)

df['Result'] = df['Result'].apply(convert_format)
df['At_score'] = df['At_score'].apply(convert_format)

# %%
df.shape
# Out:
# (1391, 15)

# %%
df.head(20)
# Out:
#     Season            Competition     Matchday Venue                 Club  \
# 0    15/16                 LaLiga           26     H         FC Barcelona
# 1    16/17                 LaLiga           25     H         FC Barcelona
# 2   Dec-13                 LaLiga           36     H          Real Madrid
# 3    22/23  UEFA Champions League  Group Stage     A  Paris Saint-Germain
# 4    15/16  UEFA Champions League      last 16     H          Real Madrid
# 5    15/16                 LaLiga           30     H          Real Madrid
# 6    15/16                 LaLiga            3     A          Real Madrid
# 7    13/14                 LaLiga           24     H         FC Barcelona
# 8    10/11  UEFA Champions League  Group Stage     A         FC Barcelona
# 9    10/11                 LaLiga            9     H         FC Barcelona
# 10   17/18                 LaLiga           31     H         FC Barcelona
# 11   15/16                 LaLiga           24     H          Real Madrid
# ...

# %%
df[['Home_Goals','Away_Goals']] = df['Result'].str.split(':', expand =True)
df.head(5)
# Out:
#    Season            Competition     Matchday Venue                 Club  \
# 0   15/16                 LaLiga           26     H         FC Barcelona
# 1   16/17                 LaLiga           25     H         FC Barcelona
# 2  Dec-13                 LaLiga           36     H          Real Madrid
# 3   22/23  UEFA Champions League  Group Stage     A  Paris Saint-Germain
# 4   15/16  UEFA Champions League      last 16     H          Real Madrid
#
#           Opponent Result Playing_Position At_score               Type  \
# 0       Sevilla FC    2:1               RW      1:1   Direct free kick
# 1  Sporting GijÃ³n    6:1               RW      1:0             Header
# 2        Malaga CF    6:2               LW      2:1  Right-footed shot
# 3       SL Benfica    1:1               AM      0:1   Left-footed shot
# 4          AS Roma    2:0               CF      1:0  Right-footed shot
#
#          Goal_assist  Main_Time  month  day  year Home_Goals Away_Goals
# ...

# %%
df['Result_Team'] = df.apply(lambda row: 'Win' if row['Home_Goals'] > row['Away_Goals'] 
                             else 'Draw' if row['Home_Goals'] == row['Away_Goals'] 
                             else 'Loss', axis=1)

# %%
df.head(10)
# Out:
#    Season            Competition     Matchday Venue                 Club  \
# 0   15/16                 LaLiga           26     H         FC Barcelona
# 1   16/17                 LaLiga           25     H         FC Barcelona
# 2  Dec-13                 LaLiga           36     H          Real Madrid
# 3   22/23  UEFA Champions League  Group Stage     A  Paris Saint-Germain
# 4   15/16  UEFA Champions League      last 16     H          Real Madrid
# 5   15/16                 LaLiga           30     H          Real Madrid
# 6   15/16                 LaLiga            3     A          Real Madrid
# 7   13/14                 LaLiga           24     H         FC Barcelona
# 8   10/11  UEFA Champions League  Group Stage     A         FC Barcelona
# 9   10/11                 LaLiga            9     H         FC Barcelona
#
#                  Opponent Result Playing_Position At_score               Type  \
# 0              Sevilla FC    2:1               RW      1:1   Direct free kick
# ...

# %%
result_counts = df.groupby(['Competition', 'Result_Team']).size().unstack()

# Plotting the bar graph
result_counts.plot(kind='barh', figsize=(10,8))

plt.title('Wins, Draws, and Losses by Competition')
plt.xlabel('Competition')
plt.ylabel('Number of Matches')
plt.legend(title='Result')

# %%
win_counts = df['Result_Team'].value_counts()

# %%
sns.barplot(x=win_counts.index, y = win_counts.values)
plt.xlabel('Result of team')
plt.ylabel('Wins')
# Out:
# Text(0, 0.5, 'Wins')

# %%
result_counts = df.groupby(['Club', 'Result_Team']).size().unstack()

# Plotting the bar graph
result_counts.plot(kind='barh', figsize=(10,8))

plt.title('Wins, Draws, and Losses by Competition')
plt.xlabel('Competition')
plt.ylabel('Number of Matches')
plt.legend(title='Result')

# %%
df.to_csv("processed_data.csv")
